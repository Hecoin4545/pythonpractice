# %%
au = 1 
 
match au:
    case 1:
        print('The case is 1')
    case 2:
        print("The case is 2")
    case default:
        print(a)
# Out:
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_12488\4040724027.py", line 3
#     match au:
#           ^
# SyntaxError: invalid syntax

# %%
# def Gmean(a=10,b=10):
#     mean = (a+b)/(a*b)
#     print(mean)
    
# Gmean(100,2)

# def badme():
#     pass

# It will Take argument as numbers 
# def Average(*num):
#     for i in num:
#         print(i)
        
# Average(1,2,3,4)


# # and if we take ** in function than it will take dictionary 


# a = [1,2,3,4,'het' , 'true']

# # This Thing will apply for both list and string 
# if "het" in a:
#     print(True)
# else:
#     print(False)
    
# Nice Method To Remember 
# lens = [i for i in range(10) if i%2 != 0 ]
# print(lens)

# Method in Python 
# len = [1,2,411,213,1]
# print(len)

# inko directly print nahi kar sakte 
# len.append(12)
# print(len)

# len.sort()
# print(len)

# len.reverse()
# print(len)

# print(len.index(2))

# # it counts the number of times an element comes 
# print(len.count(1))

# # copy method se hum koi bhi list ko copy kar sakte hai and bad mai hum uss second list ko change karenge toh first mai kuch change nhi ayega 
# m = len.copy()
# print(m)

# len.insert(1,1234)
# print(len)

# # extend method se hum ek list ko dusari list ke sath join kar sakte hai 
# m = [1,2,3,4]
# n = [5,6,7,8]
# m.extend(n)
# print(m)



# tuple 
# tup  = (1,2,3,4)
# print(tup)
# agar ek hi value ho toh vo tuple nahi count  karega like (1) ye ek interger datatype count hoga 
# Tuple ko mai change nhi kar sakta like tup[0] = 1 asa nhi ho sakta bro ye python hai
# tuple ko directly nhi change kar sakte usko phele list mai convert karna padega than only we can make changes and convert it to list again 
# if 1 in tup:
#     print(True)
    
# method in tuple 
# t = (12,2)
# t2 = (12,321,1)
# t3 = t + t2
# print(t3)

# we can count the number of times an element comes 
# t4 = (1,2,3,4,4,4,21,34,4)
# print(t4.count(4))

# Provide us the first element index where the tuple comes
# print(t4.index(4))

# print(len(t4))
# first numeber is the elment that we need to find second element is the starting index number 3 is ending index number 
# a = t4.index(4,4,6)
# print(a)


# f-string in python

# old style in python 
# letter = 'hello everyone myself {} i am learning {}'
# name = 'het'
# ler = 'python'
# letter = letter.format(name , ler)
# print(letter)


# new style 
# lets = f'my name is {name} and i am leaning {ler}'
# print(lets)



# resursion mai function  ke under ek function hota hai

# def fibonnaic(n):
#     if(n == 0):
#         return 0
#     elif(n == 1):
#         return 1
#     else:
#         return fibonnaic(n-1) + fibonnaic(n-2)
    

# fibonnaic(5)
        
    
# set theory ki methods ek bar dhek kar practice kar lena bro 
# Sets are ordered and python dictionaries are unordered 

# dictionary 
# dic = {
#     1:'het',
#     2:'kalp',
#     3:'Aryan',
#     'name':"enginner"
# }

# print(dic[2])
# print(dic)
# print(dic['name'])
# print(dic.get('name'))
# print(dic.keys())
# print(dic.values())
# print(dic.items())

# ep = {
#     1:'het',
#     2:'kalp',
#     3:'shlok'
# }

# ep2 = {
#     3:'aryan',
#     4:'preet'
# }

# p = ep.update(ep2)
# print(ep)

# removes the element that keys is being provided 
# ep.pop(4)

# popitems removes the last elements 
# ep.popitem()



# loops ke sath else statement 
# for i in range(5):
#     print(i)
# else:
#     print('bas ho gaya')

# check exeception handling in python and finally code and raise-valueerror

# if else short hand statement 
# a = 1
# b = 2

# print("a") if a<b else print("b is greater")

# a = [1,2,3,4,6,5]
# for index , items in enumerate(a , start=1):
#     print(items)
#     if(index == 3):
#         print('this is: ' , items)

# note: dir command is used to find out all the function and properties in a import thing like dir(math) , pandas etc etc 
# note : if __name__ == "__main__" this is used to avoid multiple output when files is imported from one place to another 
# note: explore os module from documentation 

# This is used to read a particular file
# f = open('file name' , 'r')
# text = f.read()
# f.close()

# This is used to create a new file or to write something in a particular file 
# f = open('file name' , 'w')

# 'a' mode is used to add some new content to the file without removing the original content 
# 'c' mode is usedto create a particular file 
# 'rt' is used to open a file in the form of text data whereas 'rb' is used to open the file in the form of binary data 

# how to write a file 
# f = open('file name' , 'w')
# f.write('write whatever  you want ')
# f.close()

# Another way to write the same thing in python 
# with open('file name' , 'a') as f:
#     f.write("write what ever you want ")


# how to file all the lines from the file 
# f = open('file name' , 'r')

# while True:
#     line = f.readline()
#     if not True:
#         break
#     print(line)

# write file is used to write multiple lines in a file 
# f = open('filename' ,'w' ) 


# if we want to edit the 6 character of the file then 
# the below line code means 10 character se line ko start karo 
# f.seek(10)

# the below line means next 5 character ko read karo
# f.read(5)

# the below line means kaha se humne seek kiya hai like idar 10 
# f.tell()

# the below code is used to restrict the file to a specific amount of letters like here 5 letter 
# with open('file name' , 'w') as f :
#     f.write('write anything')
#     f.truncate(5)
    
# with open('above file name' , 'r') as f:
#     f.read()

# lamda func: it is just like a function that is used just like a function
# name = lambda x: x*2
# print(name(2))

# map filter and reduce  javascript wala concept 
# map
# def cube(x):
#     return x*x*x

# l = [1,2,3,4,5,6]
# phele toh map ko dedo function then use dedo thing jis par vo function apply karna chate ho and then convert it into list 
# newl = list(map(cube , l))
# print(newl)

# filter
# isme bhi same as map but ye sirf filter karta hai 
# def filter_func(x):
#     return x>4

# newl = list(filter(filter_func , l))
# print(newl)

# reduce function 
# firstly we have to import it 
# from functools import reduce

# isme ye phele first two element ko lega them unka sum karega then vo sum wali cheez ko lekar 3 element ke sath sum karega and so on 
# sum  = reduce(lambda x , y : x+y , l)
# print(sum)

# is and == ka difference 
# a = 4
# b = '4'

# a is b false
# a == b false

# this basically means ke ye immutable objects ko 'is' false dega and ''=='' values check karta hai 


# How to create classes in python 
# class Person:
#     name = 'het'
#     occupation = 'software engineer'
#     networth = 10
#     def info(self):
#         print(f'My Name Is {self.name} And I Am A {self.occupation}')
              
# a = Person()
# a.name = 'kalp'
# a.oocupation = 'jee'
# b = Person()
# b.name = 'aryan'
# b.occupation = 'all rounder'
# a.info()
# b.info()

# constructer in python 
# Its like a default function that will always run once the function is declared 
# class post():
#     def __init__(self , a ,b ):
#         print('THis is a default function')
#         self.name = a 
#         self.occupation = b
#     def info(self):
#         print(f'{self.name} is a {self.occupation}')
        
# a = post('het' , 'developer')
# a.info()

# decoraters in python :- see that in documentation 

# getter and setters in python :- see that in other video or documentation


# inheritence in python 
# class Employee:
#   def __init__(self, name, id):
#     self.name = name
#     self.id = id 

#   def showDetails(self):
#     print(f"The name of Employee: {self.id} is {self.name}")

# class Programmer(Employee):
#   def showLanguage(self):
#     print("The default langauge is Python")


# e1 = Employee("Rohan Das", 400)
# e1.showDetails()
# e2 = Programmer("Harry", 4100)
# e2.showDetails()
# e2.showLanguage()

# Public private and protected handlers 
# class employ():
#     def __init__(self):
# #         private handler
#         self.__name = 'het' 
# a = employ()
# print(a._employ__name)



# protected handler 
# class Student:
#     def __init__(self):
#         self._name = "Harry"

#     def _funName(self):      # protected method
#         return "CodeWithHarry"

# class Subject(Student):       #inherited class
#     pass

# obj = Student()
# obj1 = Subject()
# print(dir(obj))

# # calling by object of Student class
# print(obj._name)      
# print(obj._funName())     
# # calling by object of Subject class
# print(obj1._name)    
# print(obj1._funName())

# '__' wali cheez directly access nhi kar sakte usko karne ke liye '_func__methodname' karna padega 


# static method is used to use just as a function but it is within the class 
# static method mai self argument nahi dena padta 
# class Math:
#     def __init__(self , num):
#         self.num = num
        
#     def addto(self,n):
#         self.num = self.num + n
#     @staticmethod
#     def add(a,b):
#         return a+ b
    
# a = Math(5)
# print(a.num)
# a.add(2,3)
# a.addto(4)
# print(a.num)
# print(a.add(1,2))        


# Instanse and Class Variable
# here the company name hecoin is associated with the whole class(class variable) where as the raises is associated with a particular data (instance variable) 
# Inta important nhi hai bas agar ek common cheez ho toh vo class ke just niche likh dena hai 
# class Employ():
#     company = 'hecoin'
#     def __init__(self,name,raises):
#         self.name = name
#         self.raises = raises
#     def showDetails(self):
#         print(f'The Name of The Employee is {self.name} in {self.company} and has {self.raises}')

# a = Employ('het' , 0.02)
# a.company = 'apple'
# a.showDetails()

# b= Employ('kalp')
# b.showDetails()



# class method in python 
# Class method is used to change the class variable 
# class Employee:
#   company = "Apple"
#   def show(self):
#     print(f"The name is {self.name} and company is {self.company}")

#   @classmethod
#   def changeCompany(cls, newCompany):
#     cls.company = newCompany


# e1 = Employee()
# e1.name = "Harry"
# e1.show()
# e1.changeCompany("Tesla")
# e1.show()
# print(Employee.company)
# Here the @classmethod is used to change the original company from apple to tesla and now it is applicable to all the people in the company 


# Class methods as alternative ye bhi padhna pagega

# dir dict and help methods 
# x = [1,2,3]
# print(dir(x))

# # agar ye cheez nhi hogi toh error dega 
# print(x.__add__)


# class Person:
#   def __init__(self, name, age):
#       self.name = name
#       self.age = age
#       self.version = 1

    
# p = Person("John", 30)
# It provide all the elements of the class in the form of dictionary
# print(p.__dict__)

# It Is Used to provide all the information about the object that you put inside it 
# print(help(Person))


# Super keyword 
# It Is basically used to takes data from the parent class like here child_method is a child class and he needs to take the data of the parent class than he can do it by using super
# class ParentClass:
#     def parent_method(self):
#         print("This is the parent method.")
# class ChildClass(ParentClass):
#     def child_method(self):
#         print("This is the child method.")
#         super().parent_method()
# child_object = ChildClass()
# child_object.child_method()
# If the method is not persent in the child class than it will directly redirect to the parent class as we have aquare all the element from parent method 

# This is the another example 
# class Employee:
#   def __init__(self, name, id):
#     self.name = name
#     self.id = id

# class Programmer(Employee):
#   def __init__(self, name, id, lang):
#     super().__init__( name, id)
#     self.lang = lang

# rohan = Employee("Rohan Das", "420")
# harry = Programmer("Harry", "2345", "Python")
# print(harry.name)
# print(harry.id)
# print(harry.lang)

# %%
# def Average(*num):
#     a = num
#     b = num(a)
#     c= sum(b)
#     return b
    
        
# Average(1,2,3,4)

# a = (1,2,3,4)
# b = list(a)
# print(a,b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12488\701810424.py in <module>
#       6
#       7
# ----> 8 Average(1,2,3,4)
#       9
#      10 # a = (1,2,3,4)
#
# ~\AppData\Local\Temp\ipykernel_12488\701810424.py in Average(*num)
#       1 def Average(*num):
#       2     a = num
# ----> 3     b = num(a)
#       4     c= sum(b)
#       5     return b
#
# TypeError: 'tuple' object is not callable
